# %%
item = (input("what have you purchase?")).lower()
print(item)
price = input("what was the price?")
quantity =("hoe much have you purchased?")

# %%
num = int(input('Write a number: '))
if num>0:
    print('The number is positive')
    if num%2==0:
        print('Number is even')
    else:
        print('Number is odd')
